# %%
import pandas as pd

# %%
my_df1 = pd.read_csv("tickets.csv")
my_df2 = pd.read_csv("airports_data.csv")

# %%
my_df1
# Out:
#          ticket_no book_ref passenger_id      passenger_name
# 0       5432000987   06B046  8149 604011    VALERIY TIKHONOV  \
# 1       5432000988   06B046  8499 420203  EVGENIYA ALEKSEEVA
# 2       5432000989   E170C3  1011 752484     ARTUR GERASIMOV
# 3       5432000990   E170C3  4849 400049       ALINA VOLKOVA
# 4       5432000991   F313DD  6615 976589       MAKSIM ZHUKOV
# ...            ...      ...          ...                 ...
# 366728  5435999869   D730BA  0474 690760      IRINA SIDOROVA
# 366729  5435999870   D730BA  6535 751108     MARIYA LAZAREVA
# 366730  5435999871   A1AD46  1596 156448      MAKSIM SERGEEV
# 366731  5435999872   7B6A53  9374 822707      NURIYA PETROVA
# 366732  5435999873   7B6A53  7380 075822       PAVEL ROMANOV
#
#                                              contact_data
# 0                               {"phone": "+70127117011"}
# 1                               {"phone": "+70378089255"}
# ...

# %%
my_df2
# Out:
#     airport_code                                       airport_name
# 0            YKS          {"en": "Yakutsk Airport", "ru": "Якутск"}  \
# 1            MJZ            {"en": "Mirny Airport", "ru": "Мирный"}
# 2            KHV  {"en": "Khabarovsk-Novy Airport", "ru": "Хабар...
# 3            PKC        {"en": "Yelizovo Airport", "ru": "Елизово"}
# 4            UUS  {"en": "Yuzhno-Sakhalinsk Airport", "ru": "Хом...
# ..           ...                                                ...
# 99           MMK       {"en": "Murmansk Airport", "ru": "Мурманск"}
# 100          ABA           {"en": "Abakan Airport", "ru": "Абакан"}
# 101          BAX         {"en": "Barnaul Airport", "ru": "Барнаул"}
# 102          AAQ  {"en": "Anapa Vityazevo Airport", "ru": "Витяз...
# 103          CNN         {"en": "Chulman Airport", "ru": "Чульман"}
#
#                                                   city
# 0                    {"en": "Yakutsk", "ru": "Якутск"}  \
# ...

# %%
my_df1.describe()
# Out:
#           ticket_no
# count  3.667330e+05
# mean   5.434026e+09
# std    1.156370e+06
# min    5.432001e+09
# 25%    5.433036e+09
# 50%    5.434026e+09
# 75%    5.435040e+09
# max    5.436000e+09

# %%
tmp = my_df1.copy(deep=True)

# %%
tmp
# Out:
#          ticket_no book_ref passenger_id      passenger_name
# 0       5432000987   06B046  8149 604011    VALERIY TIKHONOV  \
# 1       5432000988   06B046  8499 420203  EVGENIYA ALEKSEEVA
# 2       5432000989   E170C3  1011 752484     ARTUR GERASIMOV
# 3       5432000990   E170C3  4849 400049       ALINA VOLKOVA
# 4       5432000991   F313DD  6615 976589       MAKSIM ZHUKOV
# ...            ...      ...          ...                 ...
# 366728  5435999869   D730BA  0474 690760      IRINA SIDOROVA
# 366729  5435999870   D730BA  6535 751108     MARIYA LAZAREVA
# 366730  5435999871   A1AD46  1596 156448      MAKSIM SERGEEV
# 366731  5435999872   7B6A53  9374 822707      NURIYA PETROVA
# 366732  5435999873   7B6A53  7380 075822       PAVEL ROMANOV
#
#                                              contact_data
# 0                               {"phone": "+70127117011"}
# 1                               {"phone": "+70378089255"}
# ...

# %%
tmp["passenger_id"].apply(lambda x: int())
