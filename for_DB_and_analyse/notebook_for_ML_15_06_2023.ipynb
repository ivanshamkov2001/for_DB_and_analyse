# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
#загружаем данные про ирисы
df = pd.read_csv('iris.csv')

# %%
df.columns = ['длина чашелистика','ширина чашелистика','длина лепестка',
              'ширина лепестка', 'класс']
df.sample(5,random_state=0)
# Out:
#      длина чашелистика  ширина чашелистика  длина лепестка  ширина лепестка
# 133                6.1                 2.6             5.6              1.4  \
# 109                6.5                 3.2             5.1              2.0
# 59                 5.0                 2.0             3.5              1.0
# 80                 5.5                 2.4             3.7              1.0
# 7                  4.4                 2.9             1.4              0.2
#
#                класс
# 133   Iris-virginica
# 109   Iris-virginica
# 59   Iris-versicolor
# 80   Iris-versicolor
# 7        Iris-setosa

# %% [markdown]
# Отметим что все признаки вещественные
# Имеем задачу классификации на 3 класса

# %%
#определяем размер выборки
print('размер выборки: ',df.shape)
# Out:
# размер выборки:  (149, 5)
# 149

# %%
sns.pairplot(df, hue='класс',height=2)

# %%
binary_dataset = df.drop(index=df.index[df['класс'] == 'Iris-setosa'])

# %%
binary_dataset.loc[binary_dataset['класс'] == 'Iris-']

# %%
binary_dataset.shape
# Out:
# (100, 5)
